# %%
# https://code.visualstudio.com/docs/python/data-science-tutorial
import pandas as pd
import numpy as np
# Read Titanic dataset
data = pd.read_csv('data.csv')

# %%
# Fix missing values and update data types
data.replace('?', np.nan, inplace= True)
data = data.astype({"age": np.float64, "fare": np.float64})

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Generate plots
fig, axs = plt.subplots(ncols=5, figsize=(30,5))
sns.violinplot(x="survived", y="age", hue="sex", data=data, ax=axs[0])
sns.pointplot(x="sibsp", y="survived", hue="sex", data=data, ax=axs[1])
sns.pointplot(x="parch", y="survived", hue="sex", data=data, ax=axs[2])
sns.pointplot(x="pclass", y="survived", hue="sex", data=data, ax=axs[3])
sns.violinplot(x="survived", y="fare", hue="sex", data=data, ax=axs[4])
# Out:
# <AxesSubplot:xlabel='survived', ylabel='fare'>

# %%
# Correlate the relationship between all variables and survival
data.replace({'male': 1, 'female': 0}, inplace=True)
data.corr().abs()[["survived"]]
# Out:
#           survived
# pclass    0.312469
# survived  1.000000
# sex       0.528693
# age       0.055513
# sibsp     0.027825
# parch     0.082660
# fare      0.244265

# %%
# Create new column relatives 
data['relatives'] = data.apply (lambda row: int((row['sibsp'] + row['parch']) > 0), axis=1)
data.corr().abs()[["survived"]]
# Out:
#            survived
# pclass     0.312469
# survived   1.000000
# sex        0.528693
# age        0.055513
# sibsp      0.027825
# parch      0.082660
# fare       0.244265
# relatives  0.201719

# %%
# Drop low correlation columns and incomplete rows
data = data[['sex', 'pclass','age','relatives','fare','survived']].dropna()
data.corr().abs()[["survived"]]
# Out:
#            survived
# sex        0.537719
# pclass     0.319979
# age        0.053958
# relatives  0.206754
# fare       0.249164
# survived   1.000000

# %%
# Divide up dataset into training and validation data
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(data[['sex','pclass','age','relatives','fare']], data.survived, test_size=0.2, random_state=0)

# %%
# Normalize data
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X_train = sc.fit_transform(x_train)
X_test = sc.transform(x_test)

# %%
# Train with Naïve Bayes algorithm
from sklearn.naive_bayes import GaussianNB
model = GaussianNB()
model.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
# Try against test data
from sklearn import metrics
predict_test = model.predict(X_test)
print(metrics.accuracy_score(y_test, predict_test))
# Out:
# 0.7464114832535885

# %%
# Use Keras to construct neural network 
from keras.models import Sequential
from keras.layers import Dense
# Create model
model = Sequential()
model.add(Dense(5, kernel_initializer = 'uniform', activation = 'relu', input_dim = 5))
model.add(Dense(5, kernel_initializer = 'uniform', activation = 'relu'))
model.add(Dense(1, kernel_initializer = 'uniform', activation = 'sigmoid'))
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 5)                 30
# _________________________________________________________________
# dense_4 (Dense)              (None, 5)                 30
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 6
# =================================================================
# Total params: 66
# Trainable params: 66
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(optimizer="adam", loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, batch_size=32, epochs=50)
# Out:
# Epoch 1/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6928 - accuracy: 0.5419
# Epoch 2/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6907 - accuracy: 0.5861
# Epoch 3/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6870 - accuracy: 0.5861
# Epoch 4/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6801 - accuracy: 0.5861
# Epoch 5/50
# 27/27 [==============================] - 0s 4ms/step - loss: 0.6680 - accuracy: 0.6041
# Epoch 6/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.6504 - accuracy: 0.7333
# Epoch 7/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6281 - accuracy: 0.7691
# Epoch 8/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.6011 - accuracy: 0.7715
# Epoch 9/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5742 - accuracy: 0.7727
# Epoch 10/50
# 27/27 [==============================] - 0s 5ms/step - loss: 0.5498 - accuracy: 0.7703
# Epoch 11/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5298 - accuracy: 0.7715
# Epoch 12/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5135 - accuracy: 0.7703
# Epoch 13/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.5014 - accuracy: 0.7727
# Epoch 14/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4934 - accuracy: 0.7751
# Epoch 15/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4875 - accuracy: 0.7751
# Epoch 16/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4832 - accuracy: 0.7787
# Epoch 17/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4788 - accuracy: 0.7775
# Epoch 18/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4751 - accuracy: 0.7787
# Epoch 19/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4722 - accuracy: 0.7823
# Epoch 20/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4696 - accuracy: 0.7835
# Epoch 21/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4679 - accuracy: 0.7835
# Epoch 22/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4665 - accuracy: 0.7835
# Epoch 23/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4650 - accuracy: 0.7859
# Epoch 24/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4636 - accuracy: 0.7835
# Epoch 25/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4623 - accuracy: 0.7811
# Epoch 26/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4614 - accuracy: 0.7811
# Epoch 27/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4606 - accuracy: 0.7823
# Epoch 28/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4593 - accuracy: 0.7823
# Epoch 29/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4584 - accuracy: 0.7823
# Epoch 30/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4581 - accuracy: 0.7823
# Epoch 31/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4565 - accuracy: 0.7847
# Epoch 32/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4557 - accuracy: 0.7847
# Epoch 33/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4553 - accuracy: 0.7859
# Epoch 34/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4551 - accuracy: 0.7847
# Epoch 35/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4543 - accuracy: 0.7847
# Epoch 36/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4537 - accuracy: 0.7835
# Epoch 37/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4530 - accuracy: 0.7847
# Epoch 38/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4527 - accuracy: 0.7835
# Epoch 39/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4525 - accuracy: 0.7823
# Epoch 40/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4514 - accuracy: 0.7811
# Epoch 41/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4512 - accuracy: 0.7811
# Epoch 42/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4510 - accuracy: 0.7823
# Epoch 43/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4503 - accuracy: 0.7835
# Epoch 44/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4506 - accuracy: 0.7811
# Epoch 45/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4497 - accuracy: 0.7859
# Epoch 46/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4499 - accuracy: 0.7847
# Epoch 47/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4498 - accuracy: 0.7871
# Epoch 48/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4488 - accuracy: 0.7835
# Epoch 49/50
# 27/27 [==============================] - 0s 2ms/step - loss: 0.4491 - accuracy: 0.7811
# Epoch 50/50
# 27/27 [==============================] - 0s 3ms/step - loss: 0.4486 - accuracy: 0.7811

# %%
# Try against test data
y_pred = model.predict_classes(X_test)
print(metrics.accuracy_score(y_test, y_pred))
